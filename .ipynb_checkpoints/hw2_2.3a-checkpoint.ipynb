# %%
import re

f = open("C:\\Users\\44380\\OneDrive\\Desktop\\hw2_word_counts_05.txt", 'r')
lines = f.readlines()
f.close()

count=0
for line in lines:
    word= re.split ('[ \n]+', line)
    count=count+int(word[1])
    #print (word[2])
x=[]
y=[]
for line in lines:
    word= re.split ('[ \n]+', line)
    word.insert(2, int(word[1])/count)
    #word[1]=int(word[1])
    
    #print (word[1])
    #alist = sorted(word[0])
    #print (word[0])
    x.insert(0,int(word[1]))
    y.insert(0,word[0])
#print (y)
z = sorted(zip(x,y))
#print (z)
print ("14 least frequent: ",z[0:14])
z = sorted(zip(x,y),reverse=True)
#print (z)
print ("15 most frequent: ", z[0:15])
add = 1
cg = "00000"
ig = "EA"
possible=[]
prob=[]
for line in lines:
    word = re.split('[ \n+]',line)
    word.insert(2, int(word[1])/count)
    #print (word)
    for i in range (0,5):
        if (cg[i] != '0'):
            if(word[0][i] != cg[i]):
                add=0
                break
        elif ((cg.find(word[0][i]) != -1)):
            #print(word[0])
            #print(word[0][i])
            add=0
            break
        if((ig.find(word[0][i]) != -1)):
            #print(word[0])
            add = 0
            break
            #continue
            #print
    if (add == 1):
        possible.insert(0,word[0])
        prob.insert(0,word[1])
        add = 0
    add = 1
#print (word)
print(possible)
print(prob)
for j in prob:
    sum = sum + int(j)
print (sum)
newp = []
for k in prob:
    newp.append(int(k)/sum)
print (newp)

p = []
q = []
for i in range (0,26):
    p.insert(0,0)
    q.insert(0,chr(90-i))
#print (p)
#print (q[25])
for i in range (0,5):
    if(cg[i]=='0'):
        for c in range (65,91):
            for word in possible:
                if(word[i]==chr(c)):
                    p[c-65] = p[c-65] + newp[possible.index(word)]
print (p)
#pmax = max(p)
sum = 0
#print (prob)
#next = q(p.index(pmax))
#print(next)
z = sorted(zip(p,q))
print (z)
# Out:
# 14 least frequent:  [(6, 'BOSAK'), (6, 'CAIXA'), (6, 'MAPCO'), (6, 'OTTIS'), (6, 'TROUP'), (7, 'CCAIR'), (7, 'CLEFT'), (7, 'FABRI'), (7, 'FOAMY'), (7, 'NIAID'), (7, 'PAXON'), (7, 'SERNA'), (7, 'TOCOR'), (7, 'YALOM')]
# 15 most frequent:  [(273077, 'THREE'), (178842, 'SEVEN'), (165764, 'EIGHT'), (159875, 'WOULD'), (157448, 'ABOUT'), (145434, 'THEIR'), (142146, 'WHICH'), (110102, 'AFTER'), (109957, 'FIRST'), (106869, 'FIFTY'), (106052, 'OTHER'), (94951, 'FORTY'), (88900, 'YEARS'), (86502, 'THERE'), (73086, 'SIXTY')]
# ['ZWICK', 'ZULUS', 'ZUBIN', 'ZORRO', 'ZOGBY', 'ZOCOR', 'ZLOTY', 'ZIPPY', 'ZILOG', 'ZILCH', 'ZIGGY', 'YUSUF', 'YUNIS', 'YUKON', 'YUKIO', 'YOUTH', 'YOURS', 'YOUNT', 'YOUNG', 'YOSSI', 'YOLKS', 'YILIN', 'XIONG', 'WYGOD', 'WRYLY', 'WRUNG', 'WRONG', 'WRITS', 'WRIST', 'WRING', 'WOUND', 'WOULD', 'WORTH', 'WORST', 'WORRY', 'WORMS', 'WORLD', 'WORKS', 'WORDS', 'WOOLF', 'WOODY', 'WOODS', 'WOLLO', 'WOLIN', 'WOLFF', 'WIXOM', 'WITTY', 'WITCO', 'WITCH', 'WISPY', 'WIRTZ', 'WIRTH', 'WINKS', 'WINGS', 'WINDY', 'WINDS', 'WINCH', 'WIMPY', 'WIMPS', 'WILLY', 'WILLS', 'WILLI', 'WILKS', 'WILDS', 'WIGHT', 'WIDTH', 'WIDOW', 'WICKS', 'WHOOP', 'WHISK', 'WHIRL', 'WHIPS', 'WHINY', 'WHIMS', 'WHIFF', 'WHICH', 'VYING', 'VUONO', 'VROOM', 'VOUCH', 'VOMIT', 'VOLVO', 'VOLTS', 'VOIGT', 'VOIDS', 'VIVID', 'VITRO', 'VISOR', 'VISIT', 'VIRUS', 'VINYL', 'VINNY', 'VINIK', 'VINCI', 'VIGOR', 'VIGIL', 'VICKY', 'VICKS', 'VICKI', 'VICHY', 'UYGUR', 'USURY', 'USURP', 'USING', 'URSUS', 'URICH', 'UPTON', 'UNTIL', 'UNRUH', 'UNITY', 'UNITS', 'UNION', 'UNIFY', 'UNIFI', 'UNFIT', 'UNCUT', 'TYSON', 'TYROL', 'TYING', 'TWIST', 'TWINS', 'TWIGS', 'TWIGG', 'TUTSI', 'TUTOR', 'TUSKS', 'TURVY', 'TUROW', 'TURNS', 'TURKS', 'TURKI', 'TURIN', 'TURCO', 'TURBO', 'TUNIS', 'TUNIC', 'TUMOR', 'TUMMY', 'TULLY', 'TULIP', 'TUFTS', 'TUDOR', 'TUCKS', 'TUCCI', 'TUBBY', 'TUBBS', 'TSUJI', 'TRYST', 'TRYON', 'TRYGG', 'TRUTT', 'TRUTH', 'TRUST', 'TRUPP', 'TRUNK', 'TRUMP', 'TRULY', 'TRUDY', 'TRUCK', 'TROUT', 'TROUP', 'TROTT', 'TROTS', 'TROST', 'TROOP', 'TROLL', 'TROIS', 'TRISH', 'TRIPS', 'TRIPP', 'TRINH', 'TRIMS', 'TRICK', 'TOXIN', 'TOXIC', 'TOWNS', 'TOUTS', 'TOURS', 'TOUGH', 'TOUCH', 'TOSCO', 'TORTS', 'TORSO', 'TORIT', 'TORCH', 'TOPSY', 'TOPPS', 'TOPOL', 'TOPIX', 'TOPIC', 'TOOTH', 'TOOLS', 'TONYS', 'TONTO', 'TONIC', 'TONGS', 'TOMMY', 'TOMBS', 'TOLLS', 'TOKYU', 'TOKYO', 'TOKOS', 'TOKIO', 'TODOR', 'TOCOR', 'TOBIN', 'TITUS', 'TITOV', 'TISCH', 'TIRGU', 'TIPSY', 'TINNY', 'TINGO', 'TIMUR', 'TIMOR', 'TIMMY', 'TIMID', 'TILTS', 'TILLS', 'TIGHT', 'TICOR', 'TICKS', 'TIBOR', 'THURS', 'THUMP', 'THUMB', 'THUGS', 'THUDS', 'THROW', 'THORP', 'THORN', 'THONG', 'THIRD', 'THINS', 'THINK', 'THING', 'THIGH', 'THICK', 'SYUFY', 'SYSCO', 'SYRUP', 'SYRON', 'SYNOD', 'SYNCH', 'SYMMS', 'SYDOW', 'SYBIL', 'SWUNG', 'SWORN', 'SWORD', 'SWOOP', 'SWOON', 'SWISS', 'SWIRL', 'SWING', 'SWIMS', 'SWIFT', 'SUWON', 'SUVIT', 'SUTRO', 'SUSHI', 'SURLY', 'SUNOL', 'SUNNY', 'SUNNI', 'SULLY', 'SUITS', 'SUING', 'SUGGS', 'SUDOL', 'SUCKS', 'SUBIC', 'SUBHI', 'STURM', 'STUNT', 'STUNG', 'STUMP', 'STULL', 'STUFF', 'STUDY', 'STUDS', 'STUCK', 'STUBS', 'STRUT', 'STRUM', 'STRUB', 'STROM', 'STROH', 'STRIP', 'STOUT', 'STOTT', 'STORY', 'STORM', 'STORK', 'STOPS', 'STOPH', 'STOOP', 'STOOL', 'STOOD', 'STONY', 'STOMP', 'STOLT', 'STOLL', 'STOIC', 'STOCK', 'STITT', 'STITH', 'STIRS', 'STINT', 'STINK', 'STING', 'STILL', 'STIFF', 'STICK', 'STICH', 'SQUID', 'SPURT', 'SPURS', 'SPURN', 'SPUNK', 'SPUDS', 'SPRIG', 'SPOUT', 'SPOTS', 'SPORT', 'SPOOR', 'SPOON', 'SPOOK', 'SPOOF', 'SPONG', 'SPOIL', 'SPOCK', 'SPLIT', 'SPITZ', 'SPITS', 'SPIRO', 'SPINS', 'SPILL', 'SPIKY', 'SPICY', 'SOYUZ', 'SOUTH', 'SOURS', 'SOUPS', 'SOUND', 'SOULS', 'SOUCY', 'SOSIN', 'SORTS', 'SORRY', 'SOROS', 'SORCI', 'SOOTY', 'SONNY', 'SONIC', 'SONGS', 'SOLTI', 'SOLOW', 'SOLOS', 'SOLON', 'SOLIS', 'SOLID', 'SOKOL', 'SOILS', 'SOGGY', 'SODOM', 'SOCKS', 'SOCIO', 'SOBOL', 'SNUFF', 'SNUCK', 'SNOWY', 'SNOWS', 'SNOUT', 'SNORT', 'SNOBS', 'SNIFF', 'SMYTH', 'SMUTS', 'SMOOT', 'SMOKY', 'SMOCK', 'SMITS', 'SMITH', 'SMIRK', 'SMICK', 'SLUSH', 'SLURS', 'SLUNG', 'SLUMS', 'SLUMP', 'SLUGS', 'SLOWS', 'SLOVO', 'SLOTS', 'SLOTH', 'SLORC', 'SLOOP', 'SLITS', 'SLIPS', 'SLING', 'SLIMY', 'SLIMS', 'SLICK', 'SKUNK', 'SKULL', 'SKITS', 'SKIRT', 'SKIPS', 'SKINS', 'SKIMP', 'SKILL', 'SKIFF', 'SKIDS', 'SIXTY', 'SIXTH', 'SISSY', 'SISON', 'SIRRI', 'SIOUX', 'SINUS', 'SINKS', 'SINGS', 'SINGH', 'SINDH', 'SIMON', 'SIMMS', 'SILOS', 'SILLY', 'SILLS', 'SILKY', 'SILKS', 'SIKHS', 'SIGUR', 'SIGNS', 'SIGLO', 'SIGHT', 'SIGHS', 'SIDON', 'SIBIU', 'SHYLY', 'SHUTS', 'SHUNS', 'SHRUM', 'SH ...
